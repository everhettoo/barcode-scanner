# %%
from importlib import reload
# from imp import reload
import matplotlib.pyplot as plt
from ipcv import cvlib, scanner

reload(cvlib)
reload(scanner)

# %%
# A function to display side-by-side visuals for comparisons.
def display(source_img, cropped_img):
    # Display the previous and current side-by-side for visual comparison.
    plt.figure(figsize=(14, 12))
    plt.subplot(1, 2, 1)
    plt.imshow(source_img, cmap='gray')
    plt.title('Source Image')

    plt.subplot(1, 2, 2)
    plt.imshow(cropped_img, cmap='gray')
    plt.title('Cropped Image')

# %%
image = cvlib.load_image('../resources/barcode/barcode101.png')
cropped, contour = scanner.detect_barcode(image=image,
                                          gamma=0.5,
                                          gaussian_ksize=(15, 15),
                                          gaussian_sigma=2,
                                          avg_ksize1=(9, 9),
                                          avg_ksize2=(3, 3),
                                          thresh_min=200,
                                          dilate_kernel=[21, 7],
                                          dilate_iteration=4,
                                          shrink_factor=6,
                                          offset=0)

# cropped = scanner.detect_barcode_v2(image=image,
#                                     gamma=0.5,
#                                     gaussian_ksize=(15, 15),
#                                     gaussian_sigma=2,
#                                     thresh_min=200,
#                                     dilate_kernel=(21, 7),
#                                     dilate_iteration=4,
#                                     shrink_factor=6,
#                                     offset=0)

display(image, cropped)
print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')

# %%
image2 = cvlib.load_image('../resources/barcode/barcode101.png')
scanner.draw_bounding_box(image2, contour, (0, 255, 0))
plt.imshow(image2, cmap='gray')

# %%
image = cvlib.load_image('../resources/barcode/barcode102.png')
cropped, contour = scanner.detect_barcode(image=image,
                                          gamma=0.5,
                                          gaussian_ksize=(15, 15),
                                          gaussian_sigma=2,
                                          avg_ksize1=(9, 9),
                                          avg_ksize2=(3, 3),
                                          thresh_min=200,
                                          dilate_kernel=[21, 7],
                                          dilate_iteration=4,
                                          shrink_factor=6,
                                          offset=0)
display(image, cropped)
print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')

# %%
image = cvlib.load_image('../resources/barcode/barcode111.png')
cropped, contour = scanner.detect_barcode(image=image,
                                          gamma=0.5,
                                          gaussian_ksize=(15, 15),
                                          gaussian_sigma=2,
                                          avg_ksize1=(9, 9),
                                          avg_ksize2=(3, 3),
                                          thresh_min=200,
                                          dilate_kernel=[21, 7],
                                          dilate_iteration=4,
                                          shrink_factor=6,
                                          offset=0)
if cropped is not None:
    display(image, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')

# %%
image = cvlib.load_image('../resources/barcode/barcode112.png')
cropped, contour = scanner.detect_barcode(image=image,
                                          gamma=0.5,
                                          gaussian_ksize=(15, 15),
                                          gaussian_sigma=2,
                                          avg_ksize1=(9, 9),
                                          avg_ksize2=(3, 3),
                                          thresh_min=230,
                                          dilate_kernel=[21, 7],
                                          dilate_iteration=4,
                                          shrink_factor=6,
                                          offset=0)
if cropped is not None:
    display(image, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')

# %%
image = cvlib.load_image('../resources/barcode/barcode113.png')
cropped, contour = scanner.detect_barcode(image=image,
                                          gamma=0.5,
                                          gaussian_ksize=(15, 15),
                                          gaussian_sigma=2,
                                          avg_ksize1=(9, 9),
                                          avg_ksize2=(3, 3),
                                          thresh_min=230,
                                          dilate_kernel=[21, 7],
                                          dilate_iteration=4,
                                          shrink_factor=6,
                                          offset=0)
if cropped is not None:
    display(image, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')

# %%
# SE = [51,7] was used since [21,7] did not work.
image = cvlib.load_image('../resources/barcode/barcode114.png')
cropped, contour = scanner.detect_barcode(image=image,
                                          gamma=0.5,
                                          gaussian_ksize=(15, 15),
                                          gaussian_sigma=2,
                                          avg_ksize1=(9, 9),
                                          avg_ksize2=(3, 3),
                                          thresh_min=200,
                                          dilate_kernel=[51, 7],
                                          dilate_iteration=4,
                                          shrink_factor=6,
                                          offset=0)
display(image, cropped)
barcode = scanner.decode_barcode(cropped)
if barcode is not None:
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
else:
    cnt = 0
    for i in range(1, 50, 5):
        ksize = (21 + i, 7)
        print(f'Attempt [{cnt}] Increasing SE kernel {ksize} ...')
        cropped, contour = scanner.detect_barcode(image=image,
                                                  gamma=0.5,
                                                  gaussian_ksize=(15, 15),
                                                  gaussian_sigma=2,
                                                  avg_ksize1=(9, 9),
                                                  avg_ksize2=(3, 3),
                                                  thresh_min=200,
                                                  dilate_kernel=ksize,
                                                  dilate_iteration=4,
                                                  shrink_factor=6,
                                                  offset=0)
        barcode = scanner.decode_barcode(cropped)
        if barcode is not None:
            print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
            break

# %%
image = cvlib.load_image('../resources/barcode/barcode120.jpg')
cropped, contour = scanner.detect_barcode(image=image,
                                          gamma=0.5,
                                          gaussian_ksize=(15, 15),
                                          gaussian_sigma=2,
                                          avg_ksize1=(9, 9),
                                          avg_ksize2=(3, 3),
                                          thresh_min=200,
                                          dilate_kernel=[21, 7],
                                          dilate_iteration=4,
                                          shrink_factor=6,
                                          offset=0)
if cropped is not None:
    display(image, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')

# %%
image = cvlib.load_image('../resources/barcode/barcode140.jpg')
cropped, contour = scanner.detect_barcode(image=image,
                                          gamma=0.5,
                                          gaussian_ksize=(15, 15),
                                          gaussian_sigma=2,
                                          avg_ksize1=(9, 9),
                                          avg_ksize2=(3, 3),
                                          thresh_min=200,
                                          dilate_kernel=[21, 7],
                                          dilate_iteration=4,
                                          shrink_factor=6,
                                          offset=0)
if cropped is not None:
    display(image, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')

# %%
image = cvlib.load_image('../resources/barcode/barcode150.jpg')
cropped, contour = scanner.detect_barcode(image=image,
                                          gamma=0.5,
                                          gaussian_ksize=(15, 15),
                                          gaussian_sigma=2,
                                          avg_ksize1=(9, 9),
                                          avg_ksize2=(3, 3),
                                          thresh_min=200,
                                          dilate_kernel=[21, 7],
                                          dilate_iteration=4,
                                          shrink_factor=6,
                                          offset=0)
if cropped is not None:
    display(image, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')

# %%
image = cvlib.load_image('../resources/barcode/barcode160.jpg')
cropped, contour = scanner.detect_barcode(image=image,
                                          gamma=0.5,
                                          gaussian_ksize=(15, 15),
                                          gaussian_sigma=2,
                                          avg_ksize1=(9, 9),
                                          avg_ksize2=(3, 3),
                                          thresh_min=200,
                                          dilate_kernel=[21, 7],
                                          dilate_iteration=4,
                                          shrink_factor=6,
                                          offset=0)
display(image, cropped)
barcode = scanner.decode_barcode(cropped)
if barcode is not None:
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
else:
    cnt = 0
    for i in range(1, 50, 5):
        ksize = (21 + i, 7)
        print(f'Attempt [{cnt}] Increasing SE kernel {ksize} ...')
        cropped, contour = scanner.detect_barcode(image=image,
                                                  gamma=0.5,
                                                  gaussian_ksize=(15, 15),
                                                  gaussian_sigma=2,
                                                  avg_ksize1=(9, 9),
                                                  avg_ksize2=(3, 3),
                                                  thresh_min=200,
                                                  dilate_kernel=(21, 7),
                                                  dilate_iteration=4,
                                                  shrink_factor=6,
                                                  offset=0)
        barcode = scanner.decode_barcode(cropped)
        if barcode is not None:
            print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
            break
