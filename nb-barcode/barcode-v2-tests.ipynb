# %%
from importlib import reload
# from imp import reload
import matplotlib.pyplot as plt
import numpy as np

from ipcv import cvlib, scanner
from config import parameters

reload(cvlib)
reload(scanner)
reload(parameters)
# Out:
# <module 'config.parameters' from '/Users/everhett/Projects/python-ws/qr-scanner/config/parameters.py'>

# %%
# A function to display side-by-side visuals for comparisons.
def display(source_img, processed_img, cropped_img, ):
    # Display the previous and current side-by-side for visual comparison.
    plt.figure(figsize=(14, 12))
    plt.subplot(1, 3, 1)
    plt.imshow(source_img, cmap='gray')
    plt.title('Source Image')

    plt.subplot(1, 3, 2)
    plt.imshow(processed_img, cmap='gray')
    plt.title('Processed Image')

    if cropped_img is not None:
        plt.subplot(1, 3, 3)
        plt.imshow(cropped_img, cmap='gray')
        plt.title('Cropped Image')

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode101.png')
cropped, processed = scanner.detect_barcode_v2(image, **parameters.v2_wide_and_high1)
display(image, processed, cropped)
if cropped is not None:
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
# Out:
# Info                : size=1,724,100, RxC=[1,050x1,642], box-ratio-on: False, attempt-limit: 3
# ----------> [BEGIN, attempt=1]
# [1] --Binarize      : at min-thresh=80, [black=87.76%, white=12.24%]
# [1] --Pixel-check   : [black=87.76%, white=12.24%] within 97% limit.
# [1] --Morphing      : dilation:erosion=[10:5]
# [1] --Contour       : found=32; min-req-area=68,964.00, max-req-area=1,206,870.00 (0.04 at rate); area should be > 4.00%
# [c:2] --Contour     : selected max-area=413,038.00 at rate=23.96, aspect-ratio=1.950108
# ----------> [END, attempt=1/3]
#
# Decoded barcode :

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode102.png')
cropped, processed = scanner.detect_barcode_v2(image, **parameters.v2_wide_and_high1)
display(image, processed, cropped)
if cropped is not None:
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
# Out:
# Info                : size=5,648,120, RxC=[1,676x3,370], box-ratio-on: False, attempt-limit: 3
# ----------> [BEGIN, attempt=1]
# [1] --Binarize      : at min-thresh=80, [black=95.82%, white=4.18%]
# [1] --Pixel-check   : [black=95.82%, white=4.18%] within 97% limit.
# [1] --Morphing      : dilation:erosion=[10:5]
# [1] --Contour       : found=111; min-req-area=225,924.80, max-req-area=3,953,684.00 (0.04 at rate); area should be > 4.00%
# [c:7] --Contour     : selected max-area=413,038.00 at rate=7.31, aspect-ratio=1.950108
# ----------> [END, attempt=1/3]
#
# Decoded barcode :

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode111.png')
cropped, processed = scanner.detect_barcode_v2(image, **parameters.v2_wide_and_high2)
image = cvlib.adjust_gamma(cvlib.convert_rgb2gray(image), 0.9)
display(image, processed, cropped)
if cropped is not None:
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
# Out:
# Info                : size=12,192,768, RxC=[4,032x3,024], box-ratio-on: False, attempt-limit: 3
# ----------> [BEGIN, attempt=1]
# [1] --Binarize      : at min-thresh=80, [black=93.68%, white=6.32%]
# [1] --Pixel-check   : [black=93.68%, white=6.32%] within 97% limit.
# [1] --Morphing      : dilation:erosion=[10:5]
# [1] --Contour       : found=214; min-req-area=487,710.72, max-req-area=8,534,937.60 (0.04 at rate); area should be > 4.00%
# [c:8] --Contour     : selected max-area=564,423.00 at rate=4.63, aspect-ratio=2.059369
# ----------> [END, attempt=1/3]
#
# Decoded barcode : 9789673395354

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode112.png')
cropped, processed = scanner.detect_barcode_v2(image, **parameters.v2_wide_and_high2)
display(image, processed, cropped)
if cropped is not None:
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
# Out:
# Info                : size=3,228,336, RxC=[1,269x2,544], box-ratio-on: False, attempt-limit: 3
# ----------> [BEGIN, attempt=1]
# [1] --Binarize      : at min-thresh=80, [black=90.73%, white=9.27%]
# [1] --Pixel-check   : [black=90.73%, white=9.27%] within 97% limit.
# [1] --Morphing      : dilation:erosion=[10:5]
# [1] --Contour       : found=14; min-req-area=129,133.44, max-req-area=2,259,835.20 (0.04 at rate); area should be > 4.00%
# [c:1] --Contour     : selected max-area=203,294.50 at rate=6.30, aspect-ratio=2.111801
# [c:2] --Contour     : selected max-area=564,343.00 at rate=17.48, aspect-ratio=2.063197
# ----------> [END, attempt=1/3]
#
# Decoded barcode : 9789673395354

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode113.png')
cropped, processed = scanner.detect_barcode_v2(image, **parameters.v2_wide_and_high2)
display(image, processed, cropped)
if cropped is not None:
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
# Out:
# Info                : size=1,734,208, RxC=[1,106x1,568], box-ratio-on: False, attempt-limit: 3
# ----------> [BEGIN, attempt=1]
# [1] --Binarize      : at min-thresh=80, [black=87.83%, white=12.17%]
# [1] --Pixel-check   : [black=87.83%, white=12.17%] within 97% limit.
# [1] --Morphing      : dilation:erosion=[10:5]
# [1] --Contour       : found=8; min-req-area=69,368.32, max-req-area=1,213,945.60 (0.04 at rate); area should be > 4.00%
# [c:3] --Contour     : selected max-area=560,820.00 at rate=32.34, aspect-ratio=2.031599
# ----------> [END, attempt=1/3]
#
# Decoded barcode : 9789673395354

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode120.jpg')
cropped, processed = scanner.detect_barcode_v2(image, **parameters.v2_narrow_and_high1)
display(image, processed, cropped)
if cropped is not None:
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
# Out:
# Info                : size=1,004,870, RxC=[782x1,285], box-ratio-on: False, attempt-limit: 5
# ----------> [BEGIN, attempt=1]
# [1] --Binarize      : at min-thresh=80, [black=44.58%, white=55.42%]
# [1] --Pixel-check   : [black=44.58%, white=55.42%] within 97% limit.
# [1] --Morphing      : dilation:erosion=[8:4]
# [1] --Contour       : found=86; min-req-area=40,194.80, max-req-area=703,409.00 (0.04 at rate); area should be > 4.00%
# [c:12] --Contour     : selected max-area=91,105.50 at rate=9.07, aspect-ratio=1.636735
# ----------> [END, attempt=1/5]
#
# Decoded barcode : 9780062852205

# %%
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode140.jpg')
cropped, processed = scanner.detect_barcode_v2(image, **parameters.v2_wide_and_high2)
display(image, processed, cropped)
if cropped is not None:
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
# Out:
# Info                : size=303,212, RxC=[343x884], box-ratio-on: False, attempt-limit: 3
# ----------> [BEGIN, attempt=1]
# [1] --Binarize      : pixel ratio exceeded limit 97% with min-threshold=80! [black=98.19%, white=1.81%]
# [1] --Binarize      : pixel ratio exceeded limit 97% with min-threshold=80!
#                       indefinite-adjustment made to min-threshold=115.2 ...
# [1] --Binarize      : reverting image with corrected min-thresh=115.2
# [1] --Binarize      : skipping attempt 1!
# ----------> [BEGIN, attempt=2]
# [2] --Pixel-check   : [black=93.03%, white=6.97%] within 97% limit.
# [2] --Morphing      : dilation:erosion=[10:5]
# [2] --Contour       : found=1; min-req-area=12,128.48, max-req-area=212,248.40 (0.04 at rate); area should be > 4.00%
# [c:1] --Contour     : selected max-area=103,128.00 at rate=34.01, aspect-ratio=2.857868
# ----------> [END, attempt=2/3]
#
# Decoded barcode : 6924239703645

# %%
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode150.jpg')
cropped, processed = scanner.detect_barcode_v2(image, **parameters.v2_wide_and_low1)
display(image, processed, cropped)
if cropped is not None:
    try:
        print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
    except Exception as e:
        print(f'Exception : {e}')
# Out:
# Info                : size=2,034,988, RxC=[1,324x1,537], box-ratio-on: False, attempt-limit: 10
# ----------> [BEGIN, attempt=1]
# [1] --Binarize      : at min-thresh=100, [black=92.57%, white=7.43%]
# [1] --Pixel-check   : [black=92.57%, white=7.43%] within 100% limit.
# [1] --Morphing      : dilation:erosion=[2:1]
# [1] --Contour       : found=411; min-req-area=81,399.52, max-req-area=1,424,491.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=2]
# [2] --Binarize      : at min-thresh=101, [black=92.49%, white=7.51%]
# [2] --Pixel-check   : [black=92.49%, white=7.51%] within 100% limit.
# [2] --Morphing      : dilation:erosion=[2:1]
# [2] --Contour       : found=409; min-req-area=81,399.52, max-req-area=1,424,491.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=3]
# [3] --Binarize      : at min-thresh=101, [black=92.49%, white=7.51%]
# [3] --Pixel-check   : [black=92.49%, white=7.51%] within 100% limit.
# [3] --Morphing      : dilation:erosion=[2:1]
# [3] --Contour       : found=409; min-req-area=81,399.52, max-req-area=1,424,491.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=4]
# [4] --Binarize      : at min-thresh=101, [black=92.49%, white=7.51%]
# [4] --Pixel-check   : [black=92.49%, white=7.51%] within 100% limit.
# [4] --Morphing      : dilation:erosion=[2:1]
# [4] --Contour       : found=409; min-req-area=81,399.52, max-req-area=1,424,491.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=5]
# [5] --Binarize      : at min-thresh=101, [black=92.49%, white=7.51%]
# [5] --Pixel-check   : [black=92.49%, white=7.51%] within 100% limit.
# [5] --Morphing      : dilation:erosion=[2:1]
# [5] --Contour       : found=409; min-req-area=81,399.52, max-req-area=1,424,491.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=6]
# [6] --Binarize      : at min-thresh=101, [black=92.49%, white=7.51%]
# [6] --Pixel-check   : [black=92.49%, white=7.51%] within 100% limit.
# [6] --Morphing      : dilation:erosion=[2:1]
# [6] --Contour       : found=409; min-req-area=81,399.52, max-req-area=1,424,491.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=7]
# [7] --Binarize      : at min-thresh=101, [black=92.49%, white=7.51%]
# [7] --Pixel-check   : [black=92.49%, white=7.51%] within 100% limit.
# [7] --Morphing      : dilation:erosion=[2:1]
# [7] --Contour       : found=409; min-req-area=81,399.52, max-req-area=1,424,491.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=8]
# [8] --Binarize      : at min-thresh=101, [black=92.49%, white=7.51%]
# [8] --Pixel-check   : [black=92.49%, white=7.51%] within 100% limit.
# [8] --Morphing      : dilation:erosion=[2:1]
# [8] --Contour       : found=409; min-req-area=81,399.52, max-req-area=1,424,491.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=9]
# [9] --Binarize      : at min-thresh=101, [black=92.49%, white=7.51%]
# [9] --Pixel-check   : [black=92.49%, white=7.51%] within 100% limit.
# [9] --Morphing      : dilation:erosion=[2:1]
# [9] --Contour       : found=409; min-req-area=81,399.52, max-req-area=1,424,491.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=10]
# [10] --Binarize      : at min-thresh=101, [black=92.49%, white=7.51%]
# [10] --Pixel-check   : [black=92.49%, white=7.51%] within 100% limit.
# [10] --Morphing      : dilation:erosion=[2:1]
# [10] --Contour       : found=409; min-req-area=81,399.52, max-req-area=1,424,491.60 (0.04 at rate); area should be > 4.00%
# ----------> [END, attempt=10/10]

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode160.jpg')
cropped, processed = scanner.detect_barcode_v2(image, **parameters.v2_general1)
display(image, processed, cropped)
if cropped is not None:
    try:
        print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
    except Exception as e:
        print(f'Exception : {e}')
# Out:
# Info                : size=12,192,768, RxC=[4,032x3,024], box-ratio-on: False, attempt-limit: 100
# ----------> [BEGIN, attempt=1]
# [1] --Binarize      : at min-thresh=110, [black=39.30%, white=60.70%]
# [1] --Pixel-check   : [black=39.30%, white=60.70%] within 100% limit.
# [1] --Morphing      : dilation:erosion=[2:1]
# [1] --Contour       : found=1185; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=2]
# [2] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [2] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [2] --Morphing      : dilation:erosion=[2:1]
# [2] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=3]
# [3] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [3] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [3] --Morphing      : dilation:erosion=[2:1]
# [3] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=4]
# [4] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [4] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [4] --Morphing      : dilation:erosion=[2:1]
# [4] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=5]
# [5] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [5] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [5] --Morphing      : dilation:erosion=[2:1]
# [5] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=6]
# [6] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [6] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [6] --Morphing      : dilation:erosion=[2:1]
# [6] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=7]
# [7] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [7] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [7] --Morphing      : dilation:erosion=[2:1]
# [7] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=8]
# [8] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [8] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [8] --Morphing      : dilation:erosion=[2:1]
# [8] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=9]
# [9] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [9] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [9] --Morphing      : dilation:erosion=[2:1]
# [9] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=10]
# [10] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [10] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [10] --Morphing      : dilation:erosion=[2:1]
# [10] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=11]
# [11] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [11] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [11] --Morphing      : dilation:erosion=[2:1]
# [11] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=12]
# [12] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [12] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [12] --Morphing      : dilation:erosion=[2:1]
# [12] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=13]
# [13] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [13] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [13] --Morphing      : dilation:erosion=[2:1]
# [13] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=14]
# [14] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [14] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [14] --Morphing      : dilation:erosion=[2:1]
# [14] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=15]
# [15] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [15] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [15] --Morphing      : dilation:erosion=[2:1]
# [15] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=16]
# [16] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [16] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [16] --Morphing      : dilation:erosion=[2:1]
# [16] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=17]
# [17] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [17] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [17] --Morphing      : dilation:erosion=[2:1]
# [17] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=18]
# [18] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [18] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [18] --Morphing      : dilation:erosion=[2:1]
# [18] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=19]
# [19] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [19] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [19] --Morphing      : dilation:erosion=[2:1]
# [19] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=20]
# [20] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [20] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [20] --Morphing      : dilation:erosion=[2:1]
# [20] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=21]
# [21] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [21] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [21] --Morphing      : dilation:erosion=[2:1]
# [21] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=22]
# [22] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [22] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [22] --Morphing      : dilation:erosion=[2:1]
# [22] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=23]
# [23] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [23] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [23] --Morphing      : dilation:erosion=[2:1]
# [23] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=24]
# [24] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [24] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [24] --Morphing      : dilation:erosion=[2:1]
# [24] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=25]
# [25] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [25] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [25] --Morphing      : dilation:erosion=[2:1]
# [25] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=26]
# [26] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [26] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [26] --Morphing      : dilation:erosion=[2:1]
# [26] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=27]
# [27] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [27] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [27] --Morphing      : dilation:erosion=[2:1]
# [27] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=28]
# [28] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [28] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [28] --Morphing      : dilation:erosion=[2:1]
# [28] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=29]
# [29] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [29] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [29] --Morphing      : dilation:erosion=[2:1]
# [29] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=30]
# [30] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [30] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [30] --Morphing      : dilation:erosion=[2:1]
# [30] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=31]
# [31] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [31] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [31] --Morphing      : dilation:erosion=[2:1]
# [31] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=32]
# [32] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [32] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [32] --Morphing      : dilation:erosion=[2:1]
# [32] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=33]
# [33] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [33] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [33] --Morphing      : dilation:erosion=[2:1]
# [33] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=34]
# [34] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [34] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [34] --Morphing      : dilation:erosion=[2:1]
# [34] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=35]
# [35] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [35] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [35] --Morphing      : dilation:erosion=[2:1]
# [35] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=36]
# [36] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [36] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [36] --Morphing      : dilation:erosion=[2:1]
# [36] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=37]
# [37] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [37] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [37] --Morphing      : dilation:erosion=[2:1]
# [37] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=38]
# [38] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [38] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [38] --Morphing      : dilation:erosion=[2:1]
# [38] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=39]
# [39] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [39] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [39] --Morphing      : dilation:erosion=[2:1]
# [39] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=40]
# [40] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [40] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [40] --Morphing      : dilation:erosion=[2:1]
# [40] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=41]
# [41] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [41] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [41] --Morphing      : dilation:erosion=[2:1]
# [41] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=42]
# [42] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [42] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [42] --Morphing      : dilation:erosion=[2:1]
# [42] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=43]
# [43] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [43] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [43] --Morphing      : dilation:erosion=[2:1]
# [43] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=44]
# [44] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [44] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [44] --Morphing      : dilation:erosion=[2:1]
# [44] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=45]
# [45] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [45] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [45] --Morphing      : dilation:erosion=[2:1]
# [45] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=46]
# [46] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [46] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [46] --Morphing      : dilation:erosion=[2:1]
# [46] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=47]
# [47] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [47] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [47] --Morphing      : dilation:erosion=[2:1]
# [47] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=48]
# [48] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [48] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [48] --Morphing      : dilation:erosion=[2:1]
# [48] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=49]
# [49] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [49] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [49] --Morphing      : dilation:erosion=[2:1]
# [49] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=50]
# [50] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [50] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [50] --Morphing      : dilation:erosion=[2:1]
# [50] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=51]
# [51] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [51] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [51] --Morphing      : dilation:erosion=[2:1]
# [51] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=52]
# [52] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [52] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [52] --Morphing      : dilation:erosion=[2:1]
# [52] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=53]
# [53] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [53] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [53] --Morphing      : dilation:erosion=[2:1]
# [53] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=54]
# [54] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [54] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [54] --Morphing      : dilation:erosion=[2:1]
# [54] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=55]
# [55] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [55] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [55] --Morphing      : dilation:erosion=[2:1]
# [55] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=56]
# [56] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [56] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [56] --Morphing      : dilation:erosion=[2:1]
# [56] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=57]
# [57] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [57] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [57] --Morphing      : dilation:erosion=[2:1]
# [57] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=58]
# [58] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [58] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [58] --Morphing      : dilation:erosion=[2:1]
# [58] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=59]
# [59] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [59] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [59] --Morphing      : dilation:erosion=[2:1]
# [59] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=60]
# [60] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [60] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [60] --Morphing      : dilation:erosion=[2:1]
# [60] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=61]
# [61] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [61] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [61] --Morphing      : dilation:erosion=[2:1]
# [61] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=62]
# [62] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [62] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [62] --Morphing      : dilation:erosion=[2:1]
# [62] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=63]
# [63] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [63] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [63] --Morphing      : dilation:erosion=[2:1]
# [63] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=64]
# [64] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [64] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [64] --Morphing      : dilation:erosion=[2:1]
# [64] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=65]
# [65] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [65] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [65] --Morphing      : dilation:erosion=[2:1]
# [65] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=66]
# [66] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [66] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [66] --Morphing      : dilation:erosion=[2:1]
# [66] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=67]
# [67] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [67] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [67] --Morphing      : dilation:erosion=[2:1]
# [67] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=68]
# [68] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [68] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [68] --Morphing      : dilation:erosion=[2:1]
# [68] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=69]
# [69] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [69] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [69] --Morphing      : dilation:erosion=[2:1]
# [69] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=70]
# [70] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [70] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [70] --Morphing      : dilation:erosion=[2:1]
# [70] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=71]
# [71] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [71] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [71] --Morphing      : dilation:erosion=[2:1]
# [71] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=72]
# [72] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [72] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [72] --Morphing      : dilation:erosion=[2:1]
# [72] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=73]
# [73] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [73] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [73] --Morphing      : dilation:erosion=[2:1]
# [73] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=74]
# [74] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [74] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [74] --Morphing      : dilation:erosion=[2:1]
# [74] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=75]
# [75] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [75] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [75] --Morphing      : dilation:erosion=[2:1]
# [75] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=76]
# [76] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [76] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [76] --Morphing      : dilation:erosion=[2:1]
# [76] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=77]
# [77] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [77] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [77] --Morphing      : dilation:erosion=[2:1]
# [77] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=78]
# [78] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [78] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [78] --Morphing      : dilation:erosion=[2:1]
# [78] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=79]
# [79] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [79] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [79] --Morphing      : dilation:erosion=[2:1]
# [79] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=80]
# [80] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [80] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [80] --Morphing      : dilation:erosion=[2:1]
# [80] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=81]
# [81] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [81] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [81] --Morphing      : dilation:erosion=[2:1]
# [81] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=82]
# [82] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [82] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [82] --Morphing      : dilation:erosion=[2:1]
# [82] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=83]
# [83] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [83] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [83] --Morphing      : dilation:erosion=[2:1]
# [83] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=84]
# [84] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [84] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [84] --Morphing      : dilation:erosion=[2:1]
# [84] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=85]
# [85] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [85] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [85] --Morphing      : dilation:erosion=[2:1]
# [85] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=86]
# [86] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [86] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [86] --Morphing      : dilation:erosion=[2:1]
# [86] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=87]
# [87] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [87] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [87] --Morphing      : dilation:erosion=[2:1]
# [87] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=88]
# [88] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [88] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [88] --Morphing      : dilation:erosion=[2:1]
# [88] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=89]
# [89] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [89] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [89] --Morphing      : dilation:erosion=[2:1]
# [89] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=90]
# [90] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [90] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [90] --Morphing      : dilation:erosion=[2:1]
# [90] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=91]
# [91] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [91] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [91] --Morphing      : dilation:erosion=[2:1]
# [91] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=92]
# [92] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [92] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [92] --Morphing      : dilation:erosion=[2:1]
# [92] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=93]
# [93] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [93] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [93] --Morphing      : dilation:erosion=[2:1]
# [93] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=94]
# [94] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [94] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [94] --Morphing      : dilation:erosion=[2:1]
# [94] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=95]
# [95] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [95] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [95] --Morphing      : dilation:erosion=[2:1]
# [95] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=96]
# [96] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [96] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [96] --Morphing      : dilation:erosion=[2:1]
# [96] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=97]
# [97] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [97] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [97] --Morphing      : dilation:erosion=[2:1]
# [97] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=98]
# [98] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [98] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [98] --Morphing      : dilation:erosion=[2:1]
# [98] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=99]
# [99] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [99] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [99] --Morphing      : dilation:erosion=[2:1]
# [99] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [BEGIN, attempt=100]
# [100] --Binarize      : at min-thresh=111, [black=39.08%, white=60.92%]
# [100] --Pixel-check   : [black=39.08%, white=60.92%] within 100% limit.
# [100] --Morphing      : dilation:erosion=[2:1]
# [100] --Contour       : found=1180; min-req-area=12,192.77, max-req-area=8,534,937.60 (0.001 at rate); area should be > 0.10%
# ----------> [END, attempt=100/100]
