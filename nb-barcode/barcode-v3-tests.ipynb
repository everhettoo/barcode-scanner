# %%
from importlib import reload
import matplotlib.pyplot as plt

from ipcv import cvlib, scanner, imutil
from config import parameters

reload(cvlib)
reload(scanner)
reload(imutil)
reload(parameters)
# Out:
# <module 'config.parameters' from '/Users/everhett/Projects/python-ws/qr-scanner/config/parameters.py'>

# %%
# A function to display side-by-side visuals for comparisons.
def display(source_img, processed_img, cropped_img, ):
    # Display the previous and current side-by-side for visual comparison.
    plt.figure(figsize=(14, 12))
    plt.subplot(1, 3, 1)
    plt.imshow(source_img, cmap='gray')
    plt.title('Source Image')

    plt.subplot(1, 3, 2)
    plt.imshow(processed_img, cmap='gray')
    plt.title('Processed Image')

    if cropped_img is not None:
        plt.subplot(1, 3, 3)
        plt.imshow(cropped_img, cmap='gray')
        plt.title('Cropped Image')

# %% [markdown]
# # Works with General Parameter (Need threshold tweeking 100 - 120)

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode101.png')
box, p = scanner.detect_barcode_v3(image, **parameters.bar1d_v3_general)
if box is not None:
    imutil.draw_bounding_box2(image, box, imutil.GREEN_COLOR)
    cropped = imutil.crop_roi2(image, box)
    display(image, p, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
else:
    print('Box is null!')
# Out:
# Info                : size=1,724,100, RxC=[1,050x1,642], box-ratio-on: False, attempt-limit: 30
# ----------> [BEGIN, attempt=1]
# [1] --Pixel-check   : [black=86.31%, white=13.69%] within 100% limit.
# [1] --Morphing      : dilation:erosion=[4:2]
# [1] --Contour       : found=169; min-req-area=68,964.00, max-req-area=1,206,870.00 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=2]
# [2] --Pixel-check   : [black=80.14%, white=17.72%] within 100% limit.
# [2] --Morphing      : dilation:erosion=[4:2]
# [2] --Contour       : found=106; min-req-area=68,964.00, max-req-area=1,206,870.00 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=3]
# [3] --Pixel-check   : [black=76.10%, white=20.82%] within 100% limit.
# [3] --Morphing      : dilation:erosion=[4:2]
# [3] --Contour       : found=70; min-req-area=68,964.00, max-req-area=1,206,870.00 (0.04 at rate); area should be > 4.00%
# ...

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode102.png')
box, p = scanner.detect_barcode_v3(image, **parameters.bar1d_v3_general)
if box is not None:
    imutil.draw_bounding_box2(image, box, imutil.GREEN_COLOR)
    cropped = imutil.crop_roi2(image, box)
    display(image, p, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
else:
    print('Box is null!')
# Out:
# Info                : size=5,648,120, RxC=[1,676x3,370], box-ratio-on: False, attempt-limit: 30
# ----------> [BEGIN, attempt=1]
# [1] --Pixel-check   : [black=94.25%, white=5.75%] within 100% limit.
# [1] --Morphing      : dilation:erosion=[4:2]
# [1] --Contour       : found=735; min-req-area=225,924.80, max-req-area=3,953,684.00 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=2]
# [2] --Pixel-check   : [black=90.68%, white=7.74%] within 100% limit.
# [2] --Morphing      : dilation:erosion=[4:2]
# [2] --Contour       : found=396; min-req-area=225,924.80, max-req-area=3,953,684.00 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=3]
# [3] --Pixel-check   : [black=89.29%, white=7.99%] within 100% limit.
# [3] --Morphing      : dilation:erosion=[4:2]
# [3] --Contour       : found=251; min-req-area=225,924.80, max-req-area=3,953,684.00 (0.04 at rate); area should be > 4.00%
# ...

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode111.png')
box, p = scanner.detect_barcode_v3(image, **parameters.bar1d_v3_general)
if box is not None:
    imutil.draw_bounding_box2(image, box, imutil.GREEN_COLOR)
    cropped = imutil.crop_roi2(image, box)
    display(image, p, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
else:
    print('Box is null!')
# Out:
# Info                : size=12,192,768, RxC=[4,032x3,024], box-ratio-on: False, attempt-limit: 30
# ----------> [BEGIN, attempt=1]
# [1] --Pixel-check   : [black=32.33%, white=67.67%] within 100% limit.
# [1] --Morphing      : dilation:erosion=[4:2]
# [1] --Contour       : found=2086; min-req-area=487,710.72, max-req-area=8,534,937.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=2]
# [2] --Pixel-check   : [black=28.93%, white=69.06%] within 100% limit.
# [2] --Morphing      : dilation:erosion=[4:2]
# [2] --Contour       : found=1599; min-req-area=487,710.72, max-req-area=8,534,937.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=3]
# [3] --Pixel-check   : [black=27.17%, white=69.67%] within 100% limit.
# [3] --Morphing      : dilation:erosion=[4:2]
# [3] --Contour       : found=1152; min-req-area=487,710.72, max-req-area=8,534,937.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=4]
# ...

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode112.png')
box, p = scanner.detect_barcode_v3(image, **parameters.bar1d_v3_general)
if box is not None:
    imutil.draw_bounding_box2(image, box, imutil.GREEN_COLOR)
    cropped = imutil.crop_roi2(image, box)
    display(image, p, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
else:
    print('Box is null!')
# Out:
# Info                : size=3,228,336, RxC=[1,269x2,544], box-ratio-on: False, attempt-limit: 30
# ----------> [BEGIN, attempt=1]
# [1] --Pixel-check   : [black=18.92%, white=81.08%] within 100% limit.
# [1] --Morphing      : dilation:erosion=[4:2]
# [1] --Contour       : found=118; min-req-area=129,133.44, max-req-area=2,259,835.20 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=2]
# [2] --Pixel-check   : [black=16.35%, white=82.61%] within 100% limit.
# [2] --Morphing      : dilation:erosion=[4:2]
# [2] --Contour       : found=290; min-req-area=129,133.44, max-req-area=2,259,835.20 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=3]
# [3] --Pixel-check   : [black=14.31%, white=83.58%] within 100% limit.
# [3] --Morphing      : dilation:erosion=[4:2]
# [3] --Contour       : found=207; min-req-area=129,133.44, max-req-area=2,259,835.20 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=4]
# ...

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode113.png')
box, p = scanner.detect_barcode_v3(image, **parameters.bar1d_v3_general)
if box is not None:
    imutil.draw_bounding_box2(image, box, imutil.GREEN_COLOR)
    cropped = imutil.crop_roi2(image, box)
    display(image, p, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
else:
    print('Box is null!')
# Out:
# Info                : size=1,734,208, RxC=[1,106x1,568], box-ratio-on: False, attempt-limit: 30
# ----------> [BEGIN, attempt=1]
# [1] --Pixel-check   : [black=34.45%, white=65.55%] within 100% limit.
# [1] --Morphing      : dilation:erosion=[4:2]
# [1] --Contour       : found=88; min-req-area=69,368.32, max-req-area=1,213,945.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=2]
# [2] --Pixel-check   : [black=29.75%, white=68.48%] within 100% limit.
# [2] --Morphing      : dilation:erosion=[4:2]
# [2] --Contour       : found=270; min-req-area=69,368.32, max-req-area=1,213,945.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=3]
# [3] --Pixel-check   : [black=25.83%, white=70.49%] within 100% limit.
# [3] --Morphing      : dilation:erosion=[4:2]
# [3] --Contour       : found=201; min-req-area=69,368.32, max-req-area=1,213,945.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=4]
# ...

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode114.png')
box, p = scanner.detect_barcode_v3(image, **parameters.bar1d_v3_general)
if box is not None:
    imutil.draw_bounding_box2(image, box, imutil.GREEN_COLOR)
    cropped = imutil.crop_roi2(image, box)
    display(image, p, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
else:
    print('Box is null!')
# Out:
# Info                : size=4,702,210, RxC=[2,182x2,155], box-ratio-on: False, attempt-limit: 30
# ----------> [BEGIN, attempt=1]
# [1] --Pixel-check   : [black=34.02%, white=65.98%] within 100% limit.
# [1] --Morphing      : dilation:erosion=[4:2]
# [1] --Contour       : found=286; min-req-area=188,088.40, max-req-area=3,291,547.00 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=2]
# [2] --Pixel-check   : [black=30.76%, white=66.92%] within 100% limit.
# [2] --Morphing      : dilation:erosion=[4:2]
# [2] --Contour       : found=478; min-req-area=188,088.40, max-req-area=3,291,547.00 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=3]
# [3] --Pixel-check   : [black=27.45%, white=69.38%] within 100% limit.
# [3] --Morphing      : dilation:erosion=[4:2]
# [3] --Contour       : found=359; min-req-area=188,088.40, max-req-area=3,291,547.00 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=4]
# ...

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode120.jpg')
box, p = scanner.detect_barcode_v3(image, **parameters.bar1d_v3_general)
if box is not None:
    imutil.draw_bounding_box2(image, box, imutil.GREEN_COLOR)
    cropped = imutil.crop_roi2(image, box)
    display(image, p, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
else:
    print('Box is null!')
# Out:
# Info                : size=1,004,870, RxC=[782x1,285], box-ratio-on: False, attempt-limit: 30
# ----------> [BEGIN, attempt=1]
# [1] --Pixel-check   : [black=21.84%, white=78.16%] within 100% limit.
# [1] --Morphing      : dilation:erosion=[4:2]
# [1] --Contour       : found=43; min-req-area=40,194.80, max-req-area=703,409.00 (0.04 at rate); area should be > 4.00%
# [c:18] --Contour     : selected max-area=266,132.50 at rate=26.48, aspect-ratio=2.409639
# ----------> [END, attempt=1/30]
#
# Decoded barcode : 9780062852205

# %%
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode140.jpg')
# Need adjustment on the min-threshold
param = parameters.bar1d_v3_general
param['min_threshold'] = 100
box, p = scanner.detect_barcode_v3(image, **param)
if box is not None:
    imutil.draw_bounding_box2(image, box, imutil.GREEN_COLOR)
    cropped = imutil.crop_roi2(image, box)
    display(image, p, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
else:
    print('Box is null!')
# Out:
# Info                : size=303,212, RxC=[343x884], box-ratio-on: False, attempt-limit: 30
# ----------> [BEGIN, attempt=1]
# [1] --Pixel-check   : [black=95.11%, white=4.89%] within 100% limit.
# [1] --Morphing      : dilation:erosion=[4:2]
# [1] --Contour       : found=79; min-req-area=12,128.48, max-req-area=212,248.40 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=2]
# [2] --Pixel-check   : [black=84.63%, white=13.04%] within 100% limit.
# [2] --Morphing      : dilation:erosion=[4:2]
# [2] --Contour       : found=45; min-req-area=12,128.48, max-req-area=212,248.40 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=3]
# [3] --Pixel-check   : [black=81.20%, white=15.94%] within 100% limit.
# [3] --Morphing      : dilation:erosion=[4:2]
# [3] --Contour       : found=16; min-req-area=12,128.48, max-req-area=212,248.40 (0.04 at rate); area should be > 4.00%
# [c:7] --Contour     : selected max-area=66,139.50 at rate=21.81, aspect-ratio=2.164835
# ...

# %%
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode500.jpg')
box, p = scanner.detect_barcode_v3(image, **parameters.bar1d_v3_general)
if box is not None:
    imutil.draw_bounding_box2(image, box, imutil.GREEN_COLOR)
    cropped = imutil.crop_roi2(image, box)
    display(image, p, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
else:
    print('Box is null!')
# Out:
# Info                : size=874,800, RxC=[810x1,080], box-ratio-on: False, attempt-limit: 30
# ----------> [BEGIN, attempt=1]
# [1] --Pixel-check   : [black=58.21%, white=41.79%] within 100% limit.
# [1] --Morphing      : dilation:erosion=[4:2]
# [1] --Contour       : found=106; min-req-area=34,992.00, max-req-area=612,360.00 (0.04 at rate); area should be > 4.00%
# [c:28] --Contour     : selected max-area=90,164.00 at rate=10.31, aspect-ratio=2.155660
# ----------> [END, attempt=1/30]
#
# Decoded barcode : 4902870762131

# %% [markdown]
# # Needs Special config

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode150.jpg')
box, p = scanner.detect_barcode_v3(image, **parameters.bar1d_v3_special)
if box is not None:
    imutil.draw_bounding_box2(image, box, imutil.GREEN_COLOR)
    cropped = imutil.crop_roi2(image, box)
    display(image, p, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
else:
    print('Box is null!')
# Out:
# Info                : size=2,034,988, RxC=[1,324x1,537], box-ratio-on: False, attempt-limit: 20
# ----------> [BEGIN, attempt=1]
# [1] --Pixel-check   : [black=91.04%, white=8.96%] within 100% limit.
# [1] --Morphing      : dilation:erosion=[2:1]
# [1] --Contour       : found=583; min-req-area=61,049.64, max-req-area=1,424,491.60 (0.03 at rate); area should be > 3.00%
# ----------> [BEGIN, attempt=2]
# [2] --Pixel-check   : [black=81.50%, white=14.42%] within 100% limit.
# [2] --Morphing      : dilation:erosion=[2:1]
# [2] --Contour       : found=442; min-req-area=61,049.64, max-req-area=1,424,491.60 (0.03 at rate); area should be > 3.00%
# ----------> [BEGIN, attempt=3]
# [3] --Pixel-check   : [black=80.21%, white=14.05%] within 100% limit.
# [3] --Morphing      : dilation:erosion=[2:1]
# [3] --Contour       : found=423; min-req-area=61,049.64, max-req-area=1,424,491.60 (0.03 at rate); area should be > 3.00%
# ----------> [BEGIN, attempt=4]
# ...

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode160.jpg')
# Need adjustment on the min-threshold
param = parameters.bar1d_v3_special
param['min_threshold'] = 100
box, p = scanner.detect_barcode_v3(image, **param)
if box is not None:
    imutil.draw_bounding_box2(image, box, imutil.GREEN_COLOR)
    cropped = imutil.crop_roi2(image, box)
    display(image, p, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
else:
    print('Box is null!')
# Out:
# Info                : size=12,192,768, RxC=[4,032x3,024], box-ratio-on: False, attempt-limit: 20
# ----------> [BEGIN, attempt=1]
# [1] --Pixel-check   : [black=41.31%, white=58.69%] within 100% limit.
# [1] --Morphing      : dilation:erosion=[2:1]
# [1] --Contour       : found=414; min-req-area=365,783.04, max-req-area=8,534,937.60 (0.03 at rate); area should be > 3.00%
# ----------> [BEGIN, attempt=2]
# [2] --Pixel-check   : [black=39.90%, white=59.14%] within 100% limit.
# [2] --Morphing      : dilation:erosion=[2:1]
# [2] --Contour       : found=498; min-req-area=365,783.04, max-req-area=8,534,937.60 (0.03 at rate); area should be > 3.00%
# ----------> [BEGIN, attempt=3]
# [3] --Pixel-check   : [black=38.29%, white=60.02%] within 100% limit.
# [3] --Morphing      : dilation:erosion=[2:1]
# [3] --Contour       : found=225; min-req-area=365,783.04, max-req-area=8,534,937.60 (0.03 at rate); area should be > 3.00%
# ----------> [BEGIN, attempt=4]
# ...

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode170.jpg')
# Need adjustment on the min-threshold
param = parameters.bar1d_v3_special
param['min_threshold'] = 80
box, p = scanner.detect_barcode_v3(image, **param)
if box is not None:
    imutil.draw_bounding_box2(image, box, imutil.GREEN_COLOR)
    cropped = imutil.crop_roi2(image, box)
    display(image, p, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
else:
    print('Box is null!')
# Out:
# Info                : size=874,800, RxC=[1,080x810], box-ratio-on: False, attempt-limit: 20
# ----------> [BEGIN, attempt=1]
# [1] --Pixel-check   : [black=65.37%, white=34.63%] within 100% limit.
# [1] --Morphing      : dilation:erosion=[2:1]
# [1] --Contour       : found=166; min-req-area=26,244.00, max-req-area=612,360.00 (0.03 at rate); area should be > 3.00%
# ----------> [BEGIN, attempt=2]
# [2] --Pixel-check   : [black=59.58%, white=38.02%] within 100% limit.
# [2] --Morphing      : dilation:erosion=[2:1]
# [2] --Contour       : found=121; min-req-area=26,244.00, max-req-area=612,360.00 (0.03 at rate); area should be > 3.00%
# ----------> [BEGIN, attempt=3]
# [3] --Pixel-check   : [black=58.67%, white=37.94%] within 100% limit.
# [3] --Morphing      : dilation:erosion=[2:1]
# [3] --Contour       : found=87; min-req-area=26,244.00, max-req-area=612,360.00 (0.03 at rate); area should be > 3.00%
# ----------> [BEGIN, attempt=4]
# ...

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode200.png')
# Need adjustment on the min-threshold
box, p = scanner.detect_barcode_v3(image, **parameters.bar1d_v3_general)
# box, p = scanner.detect_barcode_v3(image, **parameters.v3_special)
if box is not None:
    imutil.draw_bounding_box2(image, box, imutil.GREEN_COLOR)
    cropped = imutil.crop_roi2(image, box)
    display(image, p, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
else:
    print('Box is null!')
# Out:
# Info                : size=872,138, RxC=[778x1,121], box-ratio-on: False, attempt-limit: 30
# ----------> [BEGIN, attempt=1]
# [1] --Pixel-check   : [black=14.75%, white=85.25%] within 100% limit.
# [1] --Morphing      : dilation:erosion=[4:2]
# [1] --Contour       : found=79; min-req-area=34,885.52, max-req-area=610,496.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=2]
# [2] --Pixel-check   : [black=11.13%, white=87.41%] within 100% limit.
# [2] --Morphing      : dilation:erosion=[4:2]
# [2] --Contour       : found=37; min-req-area=34,885.52, max-req-area=610,496.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=3]
# [3] --Pixel-check   : [black=9.30%, white=88.85%] within 100% limit.
# [3] --Morphing      : dilation:erosion=[4:2]
# [3] --Contour       : found=19; min-req-area=34,885.52, max-req-area=610,496.60 (0.04 at rate); area should be > 4.00%
# ----------> [BEGIN, attempt=4]
# ...

# %%
reload(cvlib)
reload(scanner)
reload(parameters)
image = cvlib.load_image('../resources/barcode/barcode501-rotated.jpg')
# Need adjustment on the min-threshold
# box, p = scanner.detect_barcode_v3(image, **parameters.v3_general)
box, p = scanner.detect_barcode_v3(image, **parameters.bar1d_v3_special)
if box is not None:
    imutil.draw_bounding_box2(image, box, imutil.GREEN_COLOR)
    cropped = imutil.crop_roi2(image, box)
    display(image, p, cropped)
    print(f'Decoded barcode : {scanner.decode_barcode(cropped)}')
else:
    print('Box is null!')
# Out:
# Info                : size=874,800, RxC=[1,080x810], box-ratio-on: False, attempt-limit: 20
# ----------> [BEGIN, attempt=1]
# [1] --Pixel-check   : [black=58.22%, white=41.78%] within 100% limit.
# [1] --Morphing      : dilation:erosion=[2:1]
# [1] --Contour       : found=89; min-req-area=26,244.00, max-req-area=612,360.00 (0.03 at rate); area should be > 3.00%
# ----------> [BEGIN, attempt=2]
# [2] --Pixel-check   : [black=55.58%, white=41.30%] within 100% limit.
# [2] --Morphing      : dilation:erosion=[2:1]
# [2] --Contour       : found=205; min-req-area=26,244.00, max-req-area=612,360.00 (0.03 at rate); area should be > 3.00%
# ----------> [BEGIN, attempt=3]
# [3] --Pixel-check   : [black=54.25%, white=41.21%] within 100% limit.
# [3] --Morphing      : dilation:erosion=[2:1]
# [3] --Contour       : found=100; min-req-area=26,244.00, max-req-area=612,360.00 (0.03 at rate); area should be > 3.00%
# ----------> [BEGIN, attempt=4]
# ...
